# %% [raw]
# ---
# title: "2024_OLC731"
# ---

# %% [markdown]
# ```{cite-packages, include = FALSE}
# # automatically create a bib database fopackages
# # add any packages you want to cite here
# knitr::write_bib(c(
#   .packages(), 'bookdown', 'tidyverse', 'tinytex'
# ), 'packages.bib')
#
# ```
#
#
#
# ```{load_packages, message=FALSE, warning=FALSE, include=FALSE}
# # remotes::install_github("mitchelloharawild/icons")
# # devtools::install_github("ropenscilabs/icon")
# # https://www.r-bloggers.com/2018/05/icon-web-icons-for-rmarkdown/
#
# # Search icons: https://fontawesome.com/v5.15/icons
# library("fontawesome")
#
# #Setup knitr
# knitr::opts_chunk$set(echo = TRUE, eval = TRUE, warning = FALSE, background = "gray85",
#                       message = FALSE, fig.width=8, fig.height=6, comment = NA,
#                       fig.align = 'center')
# ```
#
# # Ders Hakkında {.unnumbered}
#
# Bu dersin amacı, R yazılımını kullanarak veri üzerinde istenilen çok değişkenli istatistiksel ve psikometrik işlemlerin yapılabilmesini sağlamaktır.
#
# Tez ve makale çalışmalarında öğrencilerimizin analizlerini R yazılımı ile hiçbir paket programa ihtiyaç duymadan kendi başlarına yapmalarını sağlamaktır.
#
# (İzlence) [**İzlence**](Izlence.html).
#
# ## Eğitmen {.unnumbered}
#
# `fontawesome::fa("user-tie", fill = "black")` [Dr. Kübra Atalay Kabasakal](https://avesis.hacettepe.edu.tr/katalay)
#
# `fontawesome::fa("envelope", fill = "black")` [kkatalay\@gmail.com](mailto:kkatalay@gmail.com){.email}
#
# `fontawesome::fa("envelope", fill = "black")` [katalay\@hacettepe.edu.tr](mailto:katalay@hacettepe.edu.tr){.email}
#
# ## Kitapla{.unnumbered}
#
# -   Atar, B., Atalay Kabasakal, K, Unsal Ozberk, E. B., Ozberk, E. H. & Kibrislioglu Uysal, N. (2020). ile Veri Analizi ve Psikometri Uygulamaları, Pegem Akademi, Ankara.`emo::ji("link")` [`emo::ji("book")`](https://pegem.net/urun/R-ile-Veri-Analizi-ve-Psikometri-Uygulamalari/60801)
#
# -   Desjardins, C. D., & Bulut, O. (2018). Handbook of educational measurement and psychometrics using R. Boca Raton, FL: CRC Press. `emo::ji("link")emo::ji("book")`
#
# -   Demir, E. Diliyle İstatistik Uygulamaları. Pegem Akademi, Ankara.(2021). `emo::ji("link")emo::ji("book")`
#
# ## Kaynakla{.unnumbered}
#
# -   Bu ders materyallerine ek olarak, öğrenmek için bidizi mükemmel kaynak vardır:
#
# -   `emo::ji("link")` [kurulumu ile ilgili bilgileiçerir.](https://psyteachr.github.io/data-skills-v2/installing-r.html)
#
# -   `emo::ji("link")` [studio ve güncellemeleile ilgili bilgileiçerir.](https://psyteachr.github.io/analysis-v2/updating-r-rstudio-and-packages.html)
#
# -
#
#     -   `emo::ji("link")`[Alana ozgu paketlerini inceleyebilirsiniz](https://cran.r*%20project.org/web/views/Psychometrics.html)
#
# -   `emo::ji("link")` `emo::ji("book")`[Cookbook](http://www.cookbook-r.com/)
#
# -   ``` emo::ji("link")``emo::ji("book") ```[Veri Bilimi için R](https://r4ds.had.co.nz/)
#
# -   `emo::ji("link")` `emo::ji("man")` [Hadley Wickham](https://hadley.nz/)
#
# -   `emo::ji("link")`[StackOverflow soru-cevap platfromu](https://stackoverflow.com/)
#
# -   Twitter'da [#rstats](https://twitter.com/search?f=tweets&q=%23rstats&src=typd) hashtag'ini arayın veya kullanın.
#
# -   e-posta gruplarındaki e-postalara `RSiteSearch ("sample.int")` "
#
# -   `emo::ji("link")`[ile ilgili farklı ücretsiz kaynakları bulabilirsiniz (kitaplar, videolar, websiteleri). Bu kaynakların bazıları başlangıç seviyesinde.](https://www.learnr4free.com/tr/index.html){.uri}
#
# -   `emo::ji("link")`[Referans kartları](https://cran.r-project.org/doc/contrib/Short-refcard.pdf)
#
# -   `emo::ji("link")`[Cheat Sheets](https://www.rstudio.com/resources/cheatsheets/)
